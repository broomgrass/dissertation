# %% [markdown]
# # 8. Chapter 3: Descriptions of Destinations
#
# The code chunks below should follow the approximate order of the chapter.

# %%
import plotly.express as px
import pandas as pd
import glob
import os
import re
import numpy as np

# %%
modelBasePath = 'python_resources\\tucode\\inprogress\\chapter2\\modeloutput\\finalmodels\\'

# %%
# make a df into a visualization

def makefig(df):
    
    df["realclass"] = df["realclass"].astype(str)
    df['realclass'] = df['realclass'].str.replace('0','other category').str.replace('1', 'travel')
    
    fig = px.scatter(df, x='pubdate', y='logistic',
                 symbol = df['realclass'],
                 symbol_map = {"travel": "circle", "other category": "triangle-down"},
                 color_discrete_map={'travel':'blue', 'other category': "red"},
                 color='realclass', hover_data=['title', 'volid'])
    return fig

# %%
def compTotals(file):

    dforig = pd.read_csv(file, index_col=0, encoding='utf8')
    df = (dforig*100).copy()  
    
    # Extract unique column names without numbers
    unique_columns = set([re.sub(r'(_[0-9]+)?$', '', item) for item in df.columns.to_list()])
    unique_columns
    
    # Create a DataFrame with average values for each unique combination of columns
    average_df = pd.DataFrame()
    
    for col in unique_columns:
        if col == 'gender_gender_au':
            
            relevant_columns = [c for c in df.columns if c.startswith('gender_gender_au') and 'vs_non' not in c]
            
            # Calculate the average along columns
            average_values = df[relevant_columns].mean(axis=1)
            #print(average_values)
    
            # Add the result to the new DataFrame
            average_df[col] = average_values
            #print('gender is done')
               
        
        
        elif col != 'gender_gender_au':
            #print('not gender!')
            # Extract columns with the current prefix
            relevant_columns = [c for c in df.columns if c.startswith(col)]
                
            # Calculate the average along columns
            average_values = df[relevant_columns].mean(axis=1)
            #print(average_values)
        
            # Add the result to the new DataFrame
            average_df[col] = average_values

    # We may still have some index entries that have multiple versions
    # so let us do some grouping
    
    # create a category, based in the index, to do grouping
    average_df['Model'] = average_df.index
    
    # Extract the common part of the indices without numbers
    average_df['Model'] = average_df['Model'].apply(lambda x: re.sub(r'(_[0-9]+)?$', '', x))
    
    # Group by the 'Group' column to combine the multiple iterations
    # and calculate the mean
    averages = average_df.groupby('Model').mean()
    
    return averages.round(1)

def compTotalsWithList(file):
    dforig = pd.read_csv(file, index_col=0, encoding='utf8')
    df = (dforig*100).copy()  
    
    # Extract unique column names without numbers
    unique_columns = set([re.sub(r'(_[0-9]+)?$', '', item) for item in df.columns.to_list()])
    unique_columns
    
    # Create a DataFrame with average values for each unique combination of columns
    average_df = pd.DataFrame()
    
    for col in unique_columns:
        if col == 'gender_gender_au':
            
            relevant_columns = [c for c in df.columns if c.startswith('gender_gender_au') and 'vs_non' not in c]
            
            # Calculate the average along columns
            average_values = df[relevant_columns].mean(axis=1)
            #print(average_values)
    
            # Add the result to the new DataFrame
            average_df[col] = average_values
            #print('gender is done')
               
        
        
        elif col != 'gender_gender_au':
            #print('not gender!')
            # Extract columns with the current prefix
            relevant_columns = [c for c in df.columns if c.startswith(col)]
                
            # Calculate the average along columns
            average_values = df[relevant_columns].mean(axis=1)
            #print(average_values)
        
            # Add the result to the new DataFrame
            average_df[col] = average_values

    # We may still have some index entries that have multiple versions
    # so let us do some grouping
    
    # create a category, based in the index, to do grouping
    average_df['Model'] = average_df.index
    
    # Extract the common part of the indices without numbers
    average_df['Model'] = average_df['Model'].apply(lambda x: re.sub(r'(_[0-9]+)?$', '', x))
    
    result_df = average_df.groupby('Model').agg(lambda x: x.dropna().round(1).tolist()).reset_index()
    
    return result_df

def compTotalsStdDev(file):
    result_df = compTotalsWithList(file)
    
    std_dev_df = result_df.set_index('Model')
    
    std_dev_df = std_dev_df.map(lambda x: np.std(x) if len(x) > 0 else np.nan)

    return std_dev_df

# %% [markdown]
# # Big Picture: Travel Writing Against the Eighteenth Century

# %%
bibSourceList = ['cox',  'brynmawr',  'ncco_c19trav',  'btw_w',
 'murray',  'leask', 'gove',  'tee',
 'btw_europe',  'andrews',  'bdanth', 'irishmcveagh',
 'robinson_w',  'ncco_travelnarr']
bibSourceList.sort()

genList = ['alltravel','lcsh_traveltag']

# %%
def accuracy_summary(folder_path):
    # Use os.path.join to create the complete path
    search_pattern = os.path.join(folder_path, '**\\**', '*_resultsummary.txt')

    # Use glob to find files matching the pattern
    result_files = glob.glob(search_pattern, recursive=True)
    result_files = [x for x in result_files if 'paceofchange' not in x]
    result_files = list(set(result_files))

    # Extract filenames before '_resultsummary.txt'
    file_info = [(os.path.splitext(os.path.basename(file))[0].rsplit('_resultsummary', 1)[0], file) for file in result_files]
    
    # create a list to hold dfs
    compList = []
    
    for source, path in file_info:
        compdf = pd.read_csv(path, sep=':', names = ['category', source])
        compdf.set_index('category', inplace=True)
        compList.append(compdf)
        
    finalCompdf = pd.concat(compList, axis=1).round(2)
    
    ### Now, we'll just take the average of the best accuracies
    
    # Extract the 'bestaccuracy' row
    accRow = finalCompdf.loc['bestaccuracy']

    averagebibsdf = pd.DataFrame({'index': accRow.index, 'bestaccuracy': accRow.values})

    # Group by the 'index' column and aggregate the 'bestaccuracy' values with commas
    averagebibsdf = averagebibsdf.groupby('index')['bestaccuracy'].agg(lambda x: ', '.join(map(str, x))).reset_index()

    # Split the 'bestaccuracy' values into a list of floats
    averagebibsdf['bestaccuracy'] = averagebibsdf['bestaccuracy'].apply(lambda x: [float(val) for val in x.split(', ')])
    
    # Calculate the average of the 'bestaccuracy' values for each row
    averagebibsdf['average_bestaccuracy'] = averagebibsdf['bestaccuracy'].apply(lambda x: sum(x) / len(x))

    # rename
    # if you want, you can return just the below
    averagebibsdf = averagebibsdf.rename(columns={'index': 'category'})
    averagebibsdf['average_bestaccuracy'] = (averagebibsdf['average_bestaccuracy']*100).round(2)

    
    # if you want to add a column for how many files there were in each sample
    sumNames = ['True positives ', 'True negatives ', 'False positives ', 'False negatives ']
    tempdf = finalCompdf[finalCompdf.index.isin(sumNames)]
    total_files_row = pd.Series(tempdf.sum(axis=0)/2, name='total files')
    # Append the 'total files' row to the original DataFrame
    finalCompdf = pd.concat([finalCompdf, total_files_row.to_frame().T])
    # Create a DataFrame containing only the 'total files' row
    filesdf = finalCompdf[finalCompdf.index == 'total files'].copy()
    # Drop duplicate columns
    filesdf = filesdf.loc[:, ~filesdf.columns.duplicated()].T

    resultDF = pd.merge(filesdf, averagebibsdf, left_index=True, right_on='category')
    resultDF = resultDF[[col for col in resultDF.columns if col != 'total files'] + ['total files']]
    resultDF = resultDF.round(1)

    resultDF.rename(columns={'category': 'Model'}, inplace=True)

    return resultDF

# %%
allaccdf = accuracy_summary(modelBasePath).sort_values('average_bestaccuracy')

# %%
allaccdf[allaccdf.Model.isin(bibSourceList + ['alltravel', 'lcsh_traveltag', 'origbib', 'lcsh_source'])]
# Out:
#               Model        bestaccuracy  average_bestaccuracy  total files
# 34  ncco_travelnarr    [0.9, 0.7, 0.85]                  81.7         10.0
# 6               cox  [0.87, 0.88, 0.87]                  87.3        300.0
# 0         alltravel  [0.86, 0.88, 0.88]                  87.3        300.0
# 38          origbib  [0.88, 0.89, 0.86]                  87.7        300.0
# 17      lcsh_source  [0.89, 0.88, 0.88]                  88.3        300.0
# 19   lcsh_traveltag     [0.9, 0.9, 0.9]                  90.0        300.0
# 12     irishmcveagh    [0.9, 0.9, 0.94]                  91.3         55.0
# 5             btw_w  [0.92, 0.91, 0.92]                  91.7        152.0
# 20            leask  [0.93, 0.94, 0.91]                  92.7         96.0
# 1           andrews  [0.94, 0.92, 0.93]                  93.0         63.0
# 4        btw_europe  [0.93, 0.93, 0.93]                  93.0         74.0
# 32           murray  [0.93, 0.94, 0.94]                  93.7        118.0
# 33     ncco_c19trav  [0.93, 0.94, 0.94]                  93.7        180.0
# 10             gove  [0.93, 0.95, 0.94]                  94.0         85.0
# 2            bdanth  [0.93, 0.96, 0.93]                  94.0         60.0
# 39       robinson_w  [0.94, 0.92, 0.96]                  94.0         45.0
# 3          brynmawr  [0.94, 0.95, 0.94]                  94.3        243.0
# 40              tee  [0.96, 0.95, 0.96]                  95.7         81.0

# %%
# Replace 'your_folder_path' with the actual path to your folder
# folder_path = modelBasePath + your_folder_path

# folder_path = modelBasePath + 'gender//'
# test = accuracy_summary(folder_path)
# test

# %%
df = pd.read_csv(modelBasePath + '\\allbibs\\allbibs.1\\alltravel.csv')
makefig(df)
# Out:
# <div>                            <div id="0c801a5c-355c-4ae5-8675-a39881f0a6b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c801a5c-355c-4ae5-8675-a39881f0a6b0")) {                    Plotly.newPlot(                        "0c801a5c-355c-4ae5-8675-a39881f0a6b0",                        [{"customdata":[["A treatise on the various kinds and qualities of foods:","0010402600"],["All's right at last: or, the history of Miss West.","0013100102"],["Louisa; or, the reward of an affectionate daughter. A novel,","0016700301"],["Maria; or, the vicarage. A novel. In two volumes. ...","0020200302"],["Sketches on various subjects; moral, literary, and political. By the","0032300400"],["On the necessity of inculcating candour and liberality of sentiment.","0038700300"],["An address to Protestant dissenters of all denominations, on the","0052300200"],["A select collection of the most interesting letters on the","0052400302"],["Thoughts on the defence of property. Addressed to the county","0052403000"],["The plays of William Shakespeare, in eight volumes, with the","0054400101"],["The peculiar advantages of the English nation; celebrated in a","0057502900"],["The constitution and government of the Germanic body. Shewing how","0064600600"],["Reflexions on the consequences of His Majesty's recovery from his","0064900500"],["The following acts of Parliament are published by order of","0067001000"],["Some observations on the trial of Mr. Thomas Carr, who","0069200300"],["Every man his own broker: or, a guide to Exchange-Alley.","0072000600"],["Some other thoughts on a parliamentary reform; in reply to","0072001900"],["The works of M. de Voltaire. Translated from the French.","0072300110"],["The history of the Emperor Manalay, and his virtuous wife:","0083701200"],["A collection of moral and sacred poems from the most","0087100103"],["Extracts from Lord Lyttelton's poetical works: viz. Soliloquy of a","0089202900"],["The modern courtier: or the ambitious statesman's advice to his","0101200900"],["Eliza Beaumont and Harriet Osborne: or, the child of doubt.","0110200301"],["Rational religion recommended; or, a caution against the evils attending","0118103200"],["A zeal for good works excited and directed: in a","0126500500"],["An ode, in two parts, Humbly Inscrib'd to the Right","0128900800"],["A sermon, occasioned by the decease of John Howard, Esq.","0131600300"],["The life of Voltaire, by the Marquis de Condorcet. To","0133800702"],["All the works of Christ in creation and providence, executed","0139701500"],["Lord Justice-Clerk reporter. Memorial for Gilbert Laurie of Polmont, Esq;","0147604300"],["A vindication of a late Essay on the transmutation of","0153201500"],["A sermon preach'd at Lincolns-Inn Chapel, on Wednesday the 10th","0169304200"],["Laws concerning the election of members of Parliament; with the","0173700400"],["Maria Cecilia: or life and adventures of the daughter of","0184300101"],["Georgina: or, memoirs of the Bellmour family. By a young","0201000202"],["[The] priest in rhime; an epistle to the Rev. and","0203901600"],["The crimes of the Kings of France, from Clovis to","0204601200"],["A treatise on bilious diseases and indigestion; with the effects","0209800200"],["An abridgment of Mr. Dumoulin's treatise on peace of soul","0220100600"],["Elements of natural philosophy delineated. By John Henry Winkler, ...","0222900602"],["A sermon preached before the monthly meeting of clergy, in","0224904000"],["Court intrigues. Or the secret history of Ardelisa, a story","0226201900"],["(with twenty capital copper-plates, including the Baron's portrait) A sequel","0238600302"],["An essay towards explaining the history and revelations of scripture","0243000300"],["The italian, or the confessional of the ...

# %%
# df = pd.read_csv(modelBasePath + 'allbibs.2\\alltravel.csv')
# makefig(df)

# %%
# df = pd.read_csv(modelBasePath + 'allbibs.3\\alltravel.csv')
# makefig(df)

# %% [markdown]
# ## Bibliographical Sources Perspectives on Each Other
# The percentages in Fig.X (the chart above) are telling insofar as they can indicate how much the models can tell them apart from the rest of the corpus. But if we’re thinking about comparisons, a similar approach can show how similar the different perspectives of travel writing are to each other, despite their differences.

# %%
# # Entire multicomp, done with version 1 of all models
# compTotalsdf = pd.read_csv(modelBasePath + 'comparisonTotals.csv')
# compTotalsdf.set_index('Unnamed: 0', inplace=True)
# compTotalsdf.sort_index(axis=1, inplace=True)
# compTotalsdf = compTotalsdf.rename_axis('category')
# compTotalsdf = compTotalsdf.round(3)*100
# compTotalsdf.sort_index(inplace=True)

# %%
# Let's compute all the comparison dfs here!
# note that I rename some categories, etc
# in part, this is because I don't want to go back into the code
# but it might also be useful for folks viewing the original data
# so beware if you are using differently named files, etc!
def organizedf(df):
    df.index = df.index.str.replace(r'^[^_]+_', '', regex=True)
    df.columns = df.columns.str.replace(r'^[^_]+_', '', regex=True)
    df.sort_index(axis=0, inplace=True)
    df.sort_index(axis=1, inplace=True)
    colList = df.columns.tolist()
    colList = [x for x in colList if x != 'category']
    for col in colList:
        df.loc[col, col] = np.nan
    return df

compTotalsdf = compTotals(modelBasePath+'\\mutual recognition\\comparisonTotals.csv')
compTotalsdf = organizedf(compTotalsdf)

compTotalsdfList = compTotalsWithList(modelBasePath+'\\mutual recognition\\comparisonTotals.csv')
compTotalsdfList = compTotalsdfList.set_index('Model')
compTotalsdfList = organizedf(compTotalsdfList)

compTotalsdfStd = compTotalsStdDev(modelBasePath+'\\mutual recognition\\comparisonTotals.csv')

compTotalsdfStd = organizedf(compTotalsdfStd)

# %%
# an average isn't especially useful - 
# it depends on what I'm including
# for example, not all of the models are trained against nontravel (gender_au_vs_non)
compTotalsdf.loc[bibSourceList, bibSourceList].mean().sort_values().mean()
# Out:
# 82.6120879120879

# %%
# compTotalsdf

# %%
bibcompTotals = compTotalsdf.loc[bibSourceList, bibSourceList]
fig = px.imshow(bibcompTotals)

fig.show()
# Out:
# <div>                            <div id="ba2c001f-a101-478e-bccf-b12df6c7e99e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba2c001f-a101-478e-bccf-b12df6c7e99e")) {                    Plotly.newPlot(                        "ba2c001f-a101-478e-bccf-b12df6c7e99e",                        [{"coloraxis":"coloraxis","name":"0","x":["andrews","bdanth","brynmawr","btw_europe","btw_w","cox","gove","irishmcveagh","leask","murray","ncco_c19trav","ncco_travelnarr","robinson_w","tee"],"y":["andrews","bdanth","brynmawr","btw_europe","btw_w","cox","gove","irishmcveagh","leask","murray","ncco_c19trav","ncco_travelnarr","robinson_w","tee"],"z":[[null,88.3,88.0,88.2,85.7,75.5,66.1,90.4,84.5,85.5,87.4,77.8,85.2,88.7],[88.3,null,90.5,85.4,87.1,82.0,82.0,78.0,88.1,86.6,84.8,83.1,89.0,88.5],[88.0,90.5,null,89.0,91.1,83.9,78.5,82.1,92.1,90.2,92.8,79.8,89.6,90.3],[88.2,85.4,89.0,null,89.8,75.1,66.3,84.3,87.2,86.3,90.8,79.6,89.4,87.5],[85.7,87.1,91.1,89.8,null,75.2,74.3,82.5,85.7,85.8,88.4,77.1,89.8,85.6],[75.5,82.0,83.9,75.1,75.2,null,70.8,75.3,79.3,78.3,77.6,76.1,73.9,76.7],[66.1,82.0,78.5,66.3,74.3,70.8,null,58.7,74.7,77.6,72.2,73.7,71.8,72.7],[90.4,78.0,82.1,84.3,82.5,75.3,58.7,null,77.7,75.7,83.4,72.2,82.9,77.4],[84.5,88.1,92.1,87.2,85.7,79.3,74.7,77.7,null,91.3,88.0,79.4,85.1,92.7],[85.5,86.6,90.2,86.3,85.8,78.3,77.6,75.7,91.3,null,88.0,78.8,85.0,93.1],[87.4,84.8,92.8,90.8,88.4,77.6,72.2,83.4,88.0,88.0,null,79.5,88.9,89.2],[77.8,83.1,79.8,79.6,77.1,76.1,73.7,72.2,79.4,78.8,79.5,null,76.3,80.8],[85.2,89.0,89.6,89.4,89.8,73.9,71.8,82.9,85.1,85.0,88.9,76.3,null,86.4],[88.7,88.5,90.3,87.5,85.6,76.7,72.7,77.4,92.7,93.1,89.2,80.8,86.4,null]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0 ...

# %%
bibcompTotals
# Out:
#                  andrews  bdanth  brynmawr  btw_europe  btw_w   cox  gove  \
# Model
# andrews              NaN    88.3      88.0        88.2   85.7  75.5  66.1
# bdanth              88.3     NaN      90.5        85.4   87.1  82.0  82.0
# brynmawr            88.0    90.5       NaN        89.0   91.1  83.9  78.5
# btw_europe          88.2    85.4      89.0         NaN   89.8  75.1  66.3
# btw_w               85.7    87.1      91.1        89.8    NaN  75.2  74.3
# cox                 75.5    82.0      83.9        75.1   75.2   NaN  70.8
# gove                66.1    82.0      78.5        66.3   74.3  70.8   NaN
# irishmcveagh        90.4    78.0      82.1        84.3   82.5  75.3  58.7
# leask               84.5    88.1      92.1        87.2   85.7  79.3  74.7
# murray              85.5    86.6      90.2        86.3   85.8  78.3  77.6
# ncco_c19trav        87.4    84.8      92.8        90.8   88.4  77.6  72.2
# ncco_travelnarr     77.8    83.1      79.8        79.6   77.1  76.1  73.7
# robinson_w          85.2    89.0      89.6        89.4   89.8  73.9  71.8
# tee                 88.7    88.5      90.3        87.5   85.6  76.7  72.7
#
#                  irishmcveagh  leask  murray  ncco_c19trav  ncco_travelnarr  \
# Model
# andrews                  90.4   84.5    85.5          87.4             77.8
# bdanth                   78.0   88.1    86.6          84.8             83.1
# brynmawr                 82.1   92.1    90.2          92.8             79.8
# btw_europe               84.3   87.2    86.3          90.8             79.6
# btw_w                    82.5   85.7    85.8          88.4             77.1
# cox                      75.3   79.3    78.3          77.6             76.1
# gove                     58.7   74.7    77.6          72.2             73.7
# irishmcveagh              NaN   77.7    75.7          83.4             72.2
# leask                    77.7    NaN    91.3          88.0             79.4
# murray                   75.7   91.3     NaN          88.0             78.8
# ncco_c19trav             83.4   88.0    88.0           NaN             79.5
# ncco_travelnarr          72.2   79.4    78.8          79.5              NaN
# robinson_w               82.9   85.1    85.0          88.9             76.3
# tee                      77.4   92.7    93.1          89.2             80.8
#
#                  robinson_w   tee
# Model
# andrews                85.2  88.7
# bdanth                 89.0  88.5
# brynmawr               89.6  90.3
# btw_europe             89.4  87.5
# btw_w                  89.8  85.6
# cox                    73.9  76.7
# gove                   71.8  72.7
# irishmcveagh           82.9  77.4
# leask                  85.1  92.7
# murray                 85.0  93.1
# ncco_c19trav           88.9  89.2
# ncco_travelnarr        76.3  80.8
# robinson_w              NaN  86.4
# tee                    86.4   NaN

# %%
compTotalsdf.loc[['cox'], bibSourceList]
# Out:
#        andrews  bdanth  brynmawr  btw_europe  btw_w  cox  gove  irishmcveagh  \
# Model
# cox       75.5    82.0      83.9        75.1   75.2  NaN  70.8          75.3
#
#        leask  murray  ncco_c19trav  ncco_travelnarr  robinson_w   tee
# Model
# cox     79.3    78.3          77.6             76.1        73.9  76.7

# %%
compTotalsdf.loc[['lcsh_traveltag'], bibSourceList]
# Out:
#                 andrews  bdanth  brynmawr  btw_europe  btw_w   cox  gove  \
# Model
# lcsh_traveltag     83.8    86.1      91.1        84.5   86.2  84.9  74.2
#
#                 irishmcveagh  leask  murray  ncco_c19trav  ncco_travelnarr  \
# Model
# lcsh_traveltag          82.0   85.9    84.7          88.5             78.1
#
#                 robinson_w   tee
# Model
# lcsh_traveltag        83.2  82.7

# %%
compTotalsdf.loc[['btw_w'], bibSourceList].T.mean()
# Out:
# Model
# btw_w    84.469231
# dtype: float64

# %%
tempdf = []
for bib in bibSourceList:
    tempdf.append(compTotalsdf.loc[[bib], bibSourceList].T.mean())
# pd.concat(tempdf).mean()

# %%
fig = px.imshow(compTotalsdf.loc[['irishmcveagh'], bibSourceList])

fig.show()
# Out:
# <div>                            <div id="5d780599-edbf-47ec-9504-8dfef01d6b51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d780599-edbf-47ec-9504-8dfef01d6b51")) {                    Plotly.newPlot(                        "5d780599-edbf-47ec-9504-8dfef01d6b51",                        [{"coloraxis":"coloraxis","name":"0","x":["andrews","bdanth","brynmawr","btw_europe","btw_w","cox","gove","irishmcveagh","leask","murray","ncco_c19trav","ncco_travelnarr","robinson_w","tee"],"y":["irishmcveagh"],"z":[[90.4,78.0,82.1,84.3,82.5,75.3,58.7,null,77.7,75.7,83.4,72.2,82.9,77.4]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}} ...

# %%
compTotalsdf.loc[['irishmcveagh'], bibSourceList].T.sort_values('irishmcveagh', ascending=True)
# Out:
# Model            irishmcveagh
# gove                     58.7
# ncco_travelnarr          72.2
# cox                      75.3
# murray                   75.7
# tee                      77.4
# leask                    77.7
# bdanth                   78.0
# brynmawr                 82.1
# btw_w                    82.5
# robinson_w               82.9
# ncco_c19trav             83.4
# btw_europe               84.3
# andrews                  90.4
# irishmcveagh              NaN

# %%
fig = px.imshow(compTotalsdf.loc[['irishmcveagh'], compTotalsdf.columns.str.contains('loc')])

fig.show()
# Out:
# <div>                            <div id="8a6fd3ef-3114-4a67-a512-86d3359eebdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a6fd3ef-3114-4a67-a512-86d3359eebdd")) {                    Plotly.newPlot(                        "8a6fd3ef-3114-4a67-a512-86d3359eebdd",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia"],"y":["irishmcveagh"],"z":[[73.7,74.2,77.2,86.6,92.6,91.9,75.9,76.0,80.8,71.6,75.6]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"typ ...

# %%
compTotalsdf.loc[['irishmcveagh'], compTotalsdf.columns.str.contains('loc')].T.sort_values('irishmcveagh')
# Out:
# Model        irishmcveagh
# loc_oceania          71.6
# loc_africa           73.7
# loc_carib            74.2
# loc_seasia           75.6
# loc_latinam          75.9
# loc_meast            76.0
# loc_easia            77.2
# loc_northam          80.8
# loc_europe           86.6
# loc_ireland          91.9
# loc_gb               92.6

# %%
compTotalsdf.loc[['cox'], bibSourceList].T
# Out:
# Model             cox
# andrews          75.5
# bdanth           82.0
# brynmawr         83.9
# btw_europe       75.1
# btw_w            75.2
# cox               NaN
# gove             70.8
# irishmcveagh     75.3
# leask            79.3
# murray           78.3
# ncco_c19trav     77.6
# ncco_travelnarr  76.1
# robinson_w       73.9
# tee              76.7

# %%
fig = px.imshow(compTotalsdf.loc[['irishmcveagh'], compTotalsdf.columns.str.contains('loc')])

fig.show()
# Out:
# <div>                            <div id="f0155788-3228-47eb-806c-fd9de6f6bc50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0155788-3228-47eb-806c-fd9de6f6bc50")) {                    Plotly.newPlot(                        "f0155788-3228-47eb-806c-fd9de6f6bc50",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia"],"y":["irishmcveagh"],"z":[[73.7,74.2,77.2,86.6,92.6,91.9,75.9,76.0,80.8,71.6,75.6]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"typ ...

# %% [markdown]
# ## Imaginary Fiction

# %%
imagCategories = ['fictitious', 'gove', 'lcsh_imaginary', 'lcsh_fiction',  'imagfiction','nontravel_fiction']

# %%
imagPath = modelBasePath + 'lcsh\\imagfiction\\'
imagPath_1 = imagPath + 'imagfiction.1\\'

# %%
allaccdf[allaccdf.Model.isin(imagCategories)]
# Out:
#                 Model        bestaccuracy  average_bestaccuracy  total files
# 7          fictitious  [0.91, 0.92, 0.86]                  89.7         38.0
# 16     lcsh_imaginary    [0.9, 0.9, 0.93]                  91.0         67.0
# 14       lcsh_fiction   [0.91, 0.9, 0.92]                  91.0         84.0
# 11        imagfiction  [0.91, 0.91, 0.92]                  91.3        179.0
# 35  nontravel_fiction  [0.93, 0.93, 0.92]                  92.7        218.0
# 10               gove  [0.93, 0.95, 0.94]                  94.0         85.0

# %%
# to see individual dfs:
df = pd.read_csv(modelBasePath + 'allbibs/allbibs.1/gove.csv')
makefig(df)
# Out:
# <div>                            <div id="53a204d7-592b-4da9-ac95-231a56e4e486" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53a204d7-592b-4da9-ac95-231a56e4e486")) {                    Plotly.newPlot(                        "53a204d7-592b-4da9-ac95-231a56e4e486",                        [{"customdata":[["Zelia in the desert. From the French. By the lady","0000300201"],["Zelia in the desert. From the French. By the lady","0000300202"],["Zelia in the desert. From the French. By the lady","0000300203"],["The life and adventures of Joe Thompson. A narrative founded","0016700501"],["The life and adventures of Joe Thompson. A narrative founded","0016700502"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700201"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700202"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700203"],["The true history of Henrietta de Bellgrave, a woman born","0020600500"],["The adventures of a kidnapped orphan.","0023900500"],["A narrative of the life and astonishing adventures of John","0027600200"],["The female American; or, the adventures of Unca Eliza Winkfield.","0028400401"],["The female American; or, the adventures of Unca Eliza Winkfield.","0028400402"],["Human vicissitudes; or, travels into unexplored regions In two volumes.","0101303401"],["Human vicissitudes; or, travels into unexplored regions In two volumes.","0101303402"],["The adventures of Capt. Greenland. Written in imitation of all","0101403501"],["The adventures of Capt. Greenland. Written in imitation of all","0101403502"],["The adventures of Capt. Greenland. Written in imitation of all","0101403503"],["The adventures of Capt. Greenland. Written in imitation of all","0101403504"],["The mother-in-Law: or, the innocent sufferer. Interspersed with the uncommon","0111501601"],["The mother-in-Law: or, the innocent sufferer. Interspersed with the uncommon","0111501602"],["The life of Charlotta Du Pont, an English lady; taken","0148400300"],["Berkeley Hall: or, the pupil of experience. A novel. In","0149602401"],["Berkeley Hall: or, the pupil of experience. A novel. In","0149602402"],["Berkeley Hall: or, the pupil of experience. A novel. In","0149602403"],["The consolidator: or memoirs of sundry transactions from the world","0159101600"],["Hannah Hewit; or, the female Crusoe. Being the history of","0247300201"],["Hannah Hewit; or, the female Crusoe. Being the history of","0247300202"],["Hannah Hewit; or, the female Crusoe. Being the history of","0247300203"],["The life, adventures, and pyracies, of the famous Captain Singleton:","0258300800"],["Iter lunare: or, a voyage to the moon. Containing some","0258401300"],["Micromegas: a comic romance. Being a severe satire upon the","0258700400"],["The life, extraordinary adventures, voyages, and surprizing escapes of Capt.","0376701300"],["The voyages, dangerous adventures and imminent escapes of Captain Richard","0388001100"],["The voyages and adventures of Captain Robert Boyle, in several","0388100100"],["The history of Charles Wentworth, Esq. In a series of","0458200601"],["The history of Charles Wentworth, Esq. In a series of","0458200602"],["The history of Charles Wentworth, Esq. In a series of","0458200603"],["A new voyage to the East Indies: viz. I. To","0560300600"],["Travels into several remote nations of the world. In four","0647100501"],["Travels into several remote nations of the world. In four","0647100502"],["The life and strange surprizing adventures of Robinson Crusoe, of","0653600100"],["The four years voyages of Capt. George Roberts; being a","0656300700"],["Ambrose and Eleanor; or, the adventures of two children deserted","0725100200"],["Ashton's memorial: or, an authentick accou ...

# %%
df = pd.read_csv(imagPath_1 + 'lcsh_imaginary.csv')
makefig(df)
# Out:
# <div>                            <div id="ca56b9d8-59de-4e02-a8e5-4041c2e46ce2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca56b9d8-59de-4e02-a8e5-4041c2e46ce2")) {                    Plotly.newPlot(                        "ca56b9d8-59de-4e02-a8e5-4041c2e46ce2",                        [{"customdata":[["To the inhabitants of the parish of - -","0224601100"],["A legal and constitutional argument against the alleged judicial right","nyp.33433009097506"],["A paraphrase and notes on six of the Epistles of","0427700100"],["A sermon on the happy recovery of His Majesty King","0311701300"],["The rights of Parliament vindicated, on occasion of the late","0348300500"],["Charles O Hara, Esq; appellant. Sir Robert Adair, bart. respondent.","0286400400"],["An act for dividing and inclosing certain open and common","1248200300"],["The letter of the Lord Cardinal Denhoff Bp. of Cesene.","0224100900"],["The theological, philosophical and miscellaneous works of the Rev. William","hvd.hxjnfe"],["Moderation, or a candid disposition towards those that differ from","0139702600"],["An answer to \"A short essay on the modes of","0398001800"],["A letter to the electors of Bridgenorth, upon the corn","hvd.hnspa2"],["The excise-Bill versify'd. To which is subjoin'd curious and particular","0803200200"],["The culture of forests; with an appendix, in which the","1294300500"],["An act for explaining and making more effectual a power","1248002900"],["A Persian epistle from Solin, chief eunuch at the Grand","1635800100"],["The form and order of the service that is to","1125400900"],["On reconciliation and communion with God. Being the substance of","0441300600"],["The life of Thomas Boulter, the noted flying highwayman; who","0232101000"],["The nightcap. By Mr. Mercier. In two volumes. ...","1038200202"],["The Abduction, or, The adventures of Major Sarney : a","inu.32000005270816"],["The adventures of Pomponius, a Roman Knight: or, the history","0594100101"],["Blighted ambition, or, The rise and fall of the Earl","njp.32101069186110"],["Memoirs of the Cardinal de Retz; Translated from the French,","1341300604"],["Memoirs of the late Pious and Rev. Gabriel D'Anville, V.D.M.","1543900102"],["The British mariner's vocabulary : or universal dictionary of technical","nyp.33433006836609"],["The life of Samuel Johnson, LL.D. / by James Boswell","mdp.39015074639330"],["The shipwreck, a poem, by William Falconer: with a sketch","nyp.33433074853908"],["Miscellanies. The second volume. By Dr. Swift, Dr. Arbuthnot, and","0990100202"],["The universal gardener's kalendar, and System of practical gardening; displaying","0179401800"],["Plays, Written by Sir John Vanbrugh. In Two Volumes. ...","1255200301"],["A collection of letters, Never before printed: written By Alexander","0191300500"],["The family picture. A play. Taken from the French of","0047100900"],["Maxims, characters, and reflections, critical, satyrical, and moral.","0032100900"],["The history of England, by David Hume.","hvd.hwnrfz"],["Essays on medical subjects, originally printed separately; to which is","0699900800"],["The gentleman angler. Containing brief and plain instructions by which","1008700600"],["Vinum Britannicum: or, an essay on the properties and effects","0542400200"],["The practical scheme of the secret disease, a gleet and","0218401700"],["The judgments of God considered. In a sermon Preached in","0680101000"],["The works of the Earls of Rochester, Roscommon, and Dorset;","0587200402"],["Logic, or rational thoughts on the powers of the human","0662402100"],["Essays on the principles of morality and natural religion. In","0036200500"],["A sermon preached at the cathedral church of Sarum, November","0200201200"],["The life of Hannah More, with a critical ...

# %%
df = pd.read_csv(imagPath_1 + 'imagfiction.csv')
makefig(df)
# Out:
# <div>                            <div id="aa369e4c-497c-4753-be4b-3c751e5ebdb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa369e4c-497c-4753-be4b-3c751e5ebdb2")) {                    Plotly.newPlot(                        "aa369e4c-497c-4753-be4b-3c751e5ebdb2",                        [{"customdata":[["Zelia in the desert. From the French. By the lady","0000300201"],["Zelia in the desert. From the French. By the lady","0000300202"],["Zelia in the desert. From the French. By the lady","0000300203"],["The capacity and extent of the human understanding; exemplified in","0012800800"],["The life and adventures of Joe Thompson. A narrative founded","0016700501"],["The life and adventures of Joe Thompson. A narrative founded","0016700502"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700201"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700202"],["Memoirs of a Scots heiress. Addressed to the Right Honourable","0018700203"],["Mordaunt. Sketches of life, characters, and manners, in various countries;","0019700101"],["Mordaunt. Sketches of life, characters, and manners, in various countries;","0019700102"],["Mordaunt. Sketches of life, characters, and manners, in various countries;","0019700103"],["A key, being observations and explanatory notes, upon the travels","0019700500"],["The brobdingnagians. Being a key to Gulliver's voyage to Brobdingnag.","0019700600"],["The flying island, &c. Being a Key to Gulliver's Voyage","0019700700"],["The kingdom of horses. Being a key to Gulliver's Voyage","0019700800"],["The true history of Henrietta de Bellgrave, a woman born","0020600500"],["The hairy giants: or a description of two islands in","0023200300"],["The adventures of a kidnapped orphan.","0023900500"],["A narrative of the life and astonishing adventures of John","0027600200"],["The female American; or, the adventures of Unca Eliza Winkfield.","0028400401"],["The female American; or, the adventures of Unca Eliza Winkfield.","0028400402"],["The life of John Buncle, Esq; containing various observations and","0028500100"],["The twins: or, the female traveller. A novel. Written by","0032901000"],["The life and extraordinary adventures, the perils and critical escapes,","0048500401"],["The life and extraordinary adventures, the perils and critical escapes,","0048500402"],["The life and extraordinary adventures, the perils and critical escapes,","0048500403"],["Man unmask'd: being a wonderful discovery lately made in the","0056000900"],["Chinese letters. Being a philosophical, historical, and critical correspondence between","0090501100"],["A woeful voyage indeed! Being a full and particular account","0093700300"],["The pilgrim: or, a picture of life. In a series","0097800401"],["The pilgrim: or, a picture of life. In a series","0097800402"],["Human vicissitudes; or, travels into unexplored regions In two volumes.","0101303401"],["Human vicissitudes; or, travels into unexplored regions In two volumes.","0101303402"],["The adventures of Capt. Greenland. Written in imitation of all","0101403501"],["The adventures of Capt. Greenland. Written in imitation of all","0101403502"],["The adventures of Capt. Greenland. Written in imitation of all","0101403503"],["The adventures of Capt. Greenland. Written in imitation of all","0101403504"],["The mother-in-Law: or, the innocent sufferer. Interspersed with the uncommon","0111501601"],["The mother-in-Law: or, the innocent sufferer. Interspersed with the uncommon","0111501602"],["The persian strip'd of his disguise: or, remarks on a","0127000700"],["Montgomery; or, scenes in Wales. In two volumes. ...","0127800301"],["Montgomery; or, scenes in Wales. In two volumes. ...","0127800302"],["The new Pilgrim's progress; or t ...

# %%
df = pd.read_csv(imagPath_1 + 'lcsh_fiction.csv')
makefig(df)
# Out:
# <div>                            <div id="f3432ac5-4237-4388-aeff-e391ed0f216d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3432ac5-4237-4388-aeff-e391ed0f216d")) {                    Plotly.newPlot(                        "f3432ac5-4237-4388-aeff-e391ed0f216d",                        [{"customdata":[["An historical view of the French Revolution, from the assembling","0003000301"],["The works of Edmund Waller, Esq; in verse and prose.","0086900500"],["Miscellanies. The first volume.","0103900301"],["A dissertation on the use and abuse of tobacco. In","0111802200"],["All the works of Christ in creation and providence, executed","0139701500"],["A table of all the accurate remarks and new discoveries,","0148500100"],["The recluse. A Fragment.","0149300800"],["Poems, by the Rev. Mr. Cawthorn. Late master of Tunbridge","0152900500"],["The discourse which carried the pr\u00e6mium at the Academy of","0158202900"],["An abstract of midwifry, for the use of the lying-in","0179401300"],["The British Plutarch, containing the lives of the most eminent","0182401203"],["The nautical almanac and astronomical ephemeris for the year 1803.","0206300900"],["The picture. A novel. By the Miss Minifies, Of Fairwater","0211800301"],["An answer to a book, entitled, the History of ruptures,","0218800400"],["A compleat view of the present epidemical distemper among the","0219001300"],["The antiquity and honourableness of the practice of merchandize. A","0224903800"],["The distinction between the ordinary and extraordinary gifts of the","0256901100"],["Poems on various subjects. By a lady.","0331601600"],["A short history of bees. In two parts. I. The","0378000900"],["A sermon preached at St. Paul's, Deptford, Kent, on June","0400300400"],["John Neilson of Chappel, appellant. John Murray of Conheath, respondent.","0406200600"],["Marriage ceremonies, as now used in all parts of the","0414400400"],["The Poems by Allan Ramsay.","0433601000"],["The adventures of Peregrine Pickle. In which are included, Memoirs","0468300103"],["\u00deor\u00f0a Anzel-cynnan: or a compleat view of the manners, customs,","0484000301"],["Strictures on the true cause of the present alarming scarcity","0488502400"],["An essay concerning pestilential contagion: occasion'd by the distemper now","0490600200"],["Homer's Hymn to Venus; translated from the Greek, with notes,","0516700200"],["Vinum Britannicum: or, an essay on the properties and effects","0542400200"],["A sermon preached at Little St. Helen's, to the society","0543300600"],["Poems on several occasions. By Michael Bruce.","0562002900"],["Daphne, a poem.","0562201900"],["The sheep-Shearing: a dramatic pastoral. In three acts. Taken from","0562303900"],["The epistles of Clio and Strephon, being a collection of","0579300500"],["The adventures of Pomponius, a Roman Knight: or, the history","0594100101"],["Nouvelles illustrations de zoologie, contenant cinquante planches enlumin\u00e9es d'oiseaux curieux,","0601400800"],["The happy life: or, the contented man. With reflections upon","0627301500"],["The diarian miscellany: consisting of all the useful and entertaining","0668400105"],["The laws of sewers; or the office and authority of","0676700800"],["The works of Walter Moyle Esq; none of which were","0687700601"],["The pious incendiaries: or, fanaticism display'd. A poem. By a","0748500400"],["An historical and genealogical account of the family of the","0750100200"],["Recreations in agriculture, natural-history, arts, and miscellaneous literature. By James","0790900103"],["Some elegiac lines, composed on the death of that faithful","0815601200"],["The common rights of subjects, defended: and the nature of","0819700200"],["The monthly catalogue: being an exact account of all books","0825 ...

# %%
imagTotalsdf = compTotalsdf.loc[imagCategories, imagCategories].copy()
imagTotalsdf
# imagTotalsdf.to_csv('finalbibs/imagtotals.csv')
# Out:
#                    fictitious  gove  lcsh_imaginary  lcsh_fiction  \
# Model
# fictitious                NaN  85.4            84.6          81.1
# gove                     85.4   NaN            90.6          92.3
# lcsh_imaginary           84.6  90.6             NaN          88.3
# lcsh_fiction             81.1  92.3            88.3           NaN
# imagfiction              85.3  90.7            92.9          90.9
# nontravel_fiction        76.7  89.6            83.9          88.8
#
#                    imagfiction  nontravel_fiction
# Model
# fictitious                85.3               76.7
# gove                      90.7               89.6
# lcsh_imaginary            92.9               83.9
# lcsh_fiction              90.9               88.8
# imagfiction                NaN               86.0
# nontravel_fiction         86.0                NaN

# %%
fig = px.imshow(imagTotalsdf.round(2))
fig.show()
# Out:
# <div>                            <div id="6e3237e9-1ef4-4dfe-8814-fd9f6cc40049" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e3237e9-1ef4-4dfe-8814-fd9f6cc40049")) {                    Plotly.newPlot(                        "6e3237e9-1ef4-4dfe-8814-fd9f6cc40049",                        [{"coloraxis":"coloraxis","name":"0","x":["fictitious","gove","lcsh_imaginary","lcsh_fiction","imagfiction","nontravel_fiction"],"y":["fictitious","gove","lcsh_imaginary","lcsh_fiction","imagfiction","nontravel_fiction"],"z":[[null,85.4,84.6,81.1,85.3,76.7],[85.4,null,90.6,92.3,90.7,89.6],[84.6,90.6,null,88.3,92.9,83.9],[81.1,92.3,88.3,null,90.9,88.8],[85.3,90.7,92.9,90.9,null,86.0],[76.7,89.6,83.9,88.8,86.0,null]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay", ...

# %% [markdown]
# ### Special Titles

# %%
allpredictions = pd.read_csv(modelBasePath+'\\surprises and predictions\\titlepredictions_averages.csv', encoding='utf8')

# %%
imagTitleSearch = ['millenium hall', 'sentimental journey through france', 'humphry clinker',
                   'travels into several remote nations of the world']
# imagTitleSearch = ['sentimental']
imagineTitles = allpredictions[allpredictions['title'].str.lower().str.contains('|'.join(imagTitleSearch), case=False)].copy()

imagineTitles[['docid','author','title','date']+imagCategories+['alltravel', 'lcsh_traveltag', 'btw_w', 'robinson_w']].sort_values('author').round(1)
# Out:
#                         docid                   author  \
# 36  dul1.ark+=13960=t4mk7258x             Scott, Sarah
# 18                 0509400601  Smollett, Tobias George
# 19                 0509400602  Smollett, Tobias George
# 20                 0509400603  Smollett, Tobias George
# 31                 1269300201         Sterne, Laurence
# 32                 1269300202         Sterne, Laurence
# 24                 0647100501          Swift, Jonathan
# 25                 0647100502          Swift, Jonathan
# 38         mdp.39015078568592          [unlisted-twdb]
#
#                                                 title  date  fictitious  gove  \
# 36  A description of Millenium Hall, and the count...  1762        95.2  86.0
# 18  The expedition of Humphry Clinker. By the auth...  1771        50.6  67.5
# 19  The expedition of Humphry Clinker. By the auth...  1771        65.4  75.3
# 20  The expedition of Humphry Clinker. By the auth...  1771        71.4  77.1
# 31  A sentimental journey through France and Italy...  1768        65.9  75.4
# 32  A sentimental journey through France and Italy...  1768        68.8  81.9
# 24  Travels into several remote nations of the wor...  1726        96.6  87.0
# 25  Travels into several remote nations of the wor...  1726        97.3  84.7
# 38  Travels into several remote nations of the wor...  1727        98.0  92.4
#
#     lcsh_imaginary  lcsh_fiction  imagfiction  nontravel_fiction  alltravel  \
# 36            99.2          85.6         96.3               96.9       36.4
# 18            80.4          71.2         83.8               76.1       41.0
# 19            86.1          79.1         88.2               83.8       50.8
# 20            93.8          78.5         89.8               84.6       67.2
# 31            94.9          74.7         72.2               86.3       43.8
# 32            96.9          76.7         78.9               92.0       55.9
# 24           100.0          86.6         97.6               77.0       86.8
# 25           100.0          85.9         98.3               79.8       84.2
# 38           100.0          90.7         99.6               97.1       94.3
#
#     lcsh_traveltag  btw_w  robinson_w
# 36            28.2   29.2        23.2
# 18            40.7   19.9        43.0
# 19            49.6   22.0        36.8
# 20            62.8   34.7        52.0
# 31            38.1   25.7        59.5
# 32            43.6   26.4        71.2
# 24            83.9   29.9        79.7
# 25            77.3   25.0        55.0
# 38            91.2   46.8        79.7

# %% [markdown]
# ## Poetry and History
#
# Let's look at these other two terms that are interesting in connection with travel writing.

# %%
poetryPath = modelBasePath + 'lcsh\\poetry\\'
poetryPath_1 = poetryPath + 'poetry.1\\'

# %%
poetryCategories = ['lcsh_title_poetry', 'nontravel_poetry']

# %%
allaccdf[allaccdf.Model.isin(poetryCategories)]
# Out:
#                 Model        bestaccuracy  average_bestaccuracy  total files
# 18  lcsh_title_poetry  [0.89, 0.89, 0.91]                  89.7         56.0
# 37   nontravel_poetry  [0.94, 0.93, 0.93]                  93.3        300.0

# %%
poetryTotalsdf = compTotalsdf.loc[['lcsh_title_poetry'], poetryCategories+bibSourceList+genList].copy()
poetryTotalsdf.T.sort_values('lcsh_title_poetry')
# Out:
# Model              lcsh_title_poetry
# gove                            60.4
# leask                           60.5
# bdanth                          63.3
# cox                             64.2
# robinson_w                      65.8
# tee                             66.9
# alltravel                       68.0
# lcsh_traveltag                  69.5
# brynmawr                        69.7
# murray                          70.4
# btw_europe                      70.8
# btw_w                           71.2
# irishmcveagh                    72.4
# ncco_travelnarr                 73.1
# ncco_c19trav                    73.6
# andrews                         74.3
# nontravel_poetry                84.5
# lcsh_title_poetry                NaN

# %%
fig = px.imshow(poetryTotalsdf.round(2))
fig.show()
# Out:
# <div>                            <div id="0277a000-17f5-4e9d-8b48-74d7182d139b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0277a000-17f5-4e9d-8b48-74d7182d139b")) {                    Plotly.newPlot(                        "0277a000-17f5-4e9d-8b48-74d7182d139b",                        [{"coloraxis":"coloraxis","name":"0","x":["lcsh_title_poetry","nontravel_poetry","andrews","bdanth","brynmawr","btw_europe","btw_w","cox","gove","irishmcveagh","leask","murray","ncco_c19trav","ncco_travelnarr","robinson_w","tee","alltravel","lcsh_traveltag"],"y":["lcsh_title_poetry"],"z":[[null,84.5,74.3,63.3,69.7,70.8,71.2,64.2,60.4,72.4,60.5,70.4,73.6,73.1,65.8,66.9,68.0,69.5]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"b ...

# %%
df = pd.read_csv(modelBasePath + 'lcsh\\poetry\\poetry.1\\' + 'lcsh_title_poetry.csv')
makefig(df)
# Out:
# <div>                            <div id="7cb5bad2-9817-44d6-a8b4-6f3580dd7112" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cb5bad2-9817-44d6-a8b4-6f3580dd7112")) {                    Plotly.newPlot(                        "7cb5bad2-9817-44d6-a8b4-6f3580dd7112",                        [{"customdata":[["The entertaining amour of Sylvander and Sylvia, a Fashionable buck,","0023100600"],["The ideas of the original rights of kings and governours,","0043900300"],["Romulus: a tragedy. From the French of Monsieur de Lamotte.","0049501700"],["An address to the committee of the county of York,","0062100100"],["Observations on a letter to the Prince of Wales, in","0071802200"],["On the death of Mr. Edmund Smith, late student of","0111501900"],["Rational religion recommended; or, a caution against the evils attending","0118103200"],["Sermons by the late Rev. Charles Peters, M.A. Rector of","0124800300"],["Moderation, or a candid disposition towards those that differ from","0139702600"],["A present for a servant-maid: or, the sure means of","0197801100"],["Plays written by Mr. John Gay, viz. The captives, a","0290201100"],["Bell's British Theatre. Consisting of the most esteemed English plays.","0292300129"],["Miscellaneous poems, by W. Gillum. To which is added a","0302101300"],["A revisal of the English translation of the Old Testament","0326000100"],["A new system of practical husbandry. By John Mills, ...","0367000105"],["Two sermons preached in the parish church of Chislehurst in","0395800400"],["Miscellanies.","0405100811"],["An essay concerning pestilential contagion: occasion'd by the distemper now","0490600200"],["A summary of universal history from the creation to the","0547400203"],["The miser: a farce of three acts, Taken from the","0555503900"],["The perpetuity, advantages, and universality of the Christian religion: a","0591600400"],["Plocacosmos: or the whole art of hair dressing; wherein is","0642900100"],["Philosophical inquiries into the laws of animal life. In six","0649000700"],["A short history of schism; for the promoting of Christian","0718001600"],["An historical treatise of an action or suit at law;","0753100300"],["Inoculation; or beauty's triumph : a poem, in two cantos.","0765800400"],["An essay on duelling. Written with a view to discountenance","0768800800"],["Nixon's Cheshire prophecy, at large; published from Lady Cowper's correct","0881500900"],["Abstracts of two acts of Parliament, passed in the thirteenth","0977100600"],["Two sermons, preached on Friday, December 13, 1776, and on","1103102600"],["Divine worship due to the whole blessed Trinity, the Father,","1141801100"],["A loyal subject's remonstrance to the Right Hon. Lord Thurlow,","1153601000"],["The British crisis; or, the disorder of the state at","1237903100"],["Penalties for separation. September 24. 1768. Memorial for William Pulteney,","1249001200"],["Unto the Right Honourable the Lords of Council and Session.","1275801900"],["The Whole book of Psalms, collected into English metre, By","1312701400"],["Illustrations of Sterne: with other essays and verses. By John","1333101300"],["To the public. Dr. Trusler is unwilling to observe, that","1534600200"],["Memoirs of the late Pious and Rev. Gabriel D'Anville, V.D.M.","1543900102"],["A bill for the better ordering of the office of","1549201100"],["Account of an elastic trochar, constructed on a new principle,","1623700200"],["An account of the dissection of an hermaphrodite dog. To","1634101900"],["A copy of the charter of the town and parish","1699300200"],["Every man in his humour. A comedy, by Ben Johnson","1780501200"],["A geological classification of rocks, with descriptive synopses of the","hvd.hw2ko9"],["The Colonial journal.","hvd.hxh1bu"],["Kearsley' ...

# %%
df = pd.read_csv(modelBasePath + 'lcsh\\poetry\\poetry.2\\' + 'lcsh_title_poetry.csv')
makefig(df)
# Out:
# <div>                            <div id="139a4a91-dd79-4653-8d88-cd1bc82d2658" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("139a4a91-dd79-4653-8d88-cd1bc82d2658")) {                    Plotly.newPlot(                        "139a4a91-dd79-4653-8d88-cd1bc82d2658",                        [{"customdata":[["Orlando and Lavinia: or, the libertine. A novel. In four","0016500401"],["Memoirs of a Magdalen: or, the history of Louisa Mildmay.","0021800701"],["The ideas of the original rights of kings and governours,","0043900300"],["Socrates, a tragedy of three acts. Translated from the French","0050200300"],["Information for Walter Millar Procurator-Fiscal of the Burgh of Perth,","0069301600"],["A reply to the Answer of the Rev. Dr. Maskelyne,","0139600400"],["A syllabus of lectures on the theory and practice of","0162000800"],["Georgina: or, memoirs of the Bellmour family. By a young","0201000202"],["To the inhabitants of the parish of - -","0224601100"],["An attempt to demonstrate the Messiahship of Jesus, from the","0248300400"],["A description of the freedom box, Voted by the City","0316902200"],["A sermon preach'd before the University of Cambridge, in Kings","0319400300"],["An introduction to, or a short discourse concerning, universal history.","0320800200"],["A practical discourse concerning death. By William Sherlock, D. D.","0343400800"],["Trial of Thomas Paine, at Guildhall, before Lord Kenyon, and","0348502100"],["A new system of practical husbandry. By John Mills, ...","0367000105"],["Galba. A dialogue on the navy.","0411100700"],["A collection of the works of that antient, faithful Servant","0445200902"],["A sermon preached before the gentlemen of the St. George's","0466303801"],["The perquisite-Monger: or the rise and fall of ingratitude. Being","0509600200"],["The British housewife: containing the most approved receipts in roasting,","0542100100"],["The catalogue of graduats, &c. in the University of Oxford,","0661500100"],["Honoria: or the day of All Souls, a poem, with","0681301100"],["Navigation spiritualized; or, a new compass for seamen. To which","0701401100"],["A sermon preached at the anniversary meeting of the Sons","0777801000"],["Bell's Edition. The committee. A comedy, by the Hon. Sir","0778401000"],["Funeral consolations: being the substance of an address delivered in","0855400500"],["Letters, written by the late Jonathan Swift, D.D. Dean of","0882300302"],["Letters, written by the late Jonathan Swift, D.D. Dean of","0902900105"],["The polite singer: a collection of choice songs, from the","1014600400"],["Memoirs of agriculture, and other oeconomical arts. By Robert Dossie.","1048500501"],["Three letters relating to the navy, Gibraltar, and Portmahon. Wrote","1080601600"],["A letter from an old cavalier, to the Reverend Mr.","1194600600"],["Bill of advocation, the Earl of Home, against Lady Jean","1276001200"],["Answers for Adam Little writer in Edinburgh, to the petition","1276404700"],["Description and use of the pocket case of mathematical instruments;","1329701000"],["Every man's pocket companion: or, Hints upon the law respecting","1506601200"],["A bill for the better ordering of the office of","1549201100"],["Proposals for printing by subscription, miscellaneous collections, with observations respecting","1567700100"],["The ladies calling in two parts. By the author of","1707800800"],["A letter to Hugh Hamilton, D.D. Dean of Armagh.","1719600700"],["Ancient and modern Malta:","chi.098604377"],["Olam haneshamoth : or, a view of the intermediate state,","hvd.ah53dq"],["Temple of the fairies / translated from the French of","hvd.hh2thc"],["An enquiry into the doctrines of necessity and predestination :","hvd.hwjn5k"],["Observations on some points relating to the ana ...

# %%
df = pd.read_csv(modelBasePath + 'lcsh\\poetry\\poetry.3\\' + 'lcsh_title_poetry.csv')
makefig(df)
# Out:
# <div>                            <div id="a85066db-88e2-4a52-9d38-47780e0a7f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a85066db-88e2-4a52-9d38-47780e0a7f54")) {                    Plotly.newPlot(                        "a85066db-88e2-4a52-9d38-47780e0a7f54",                        [{"customdata":[["A complete analysis or abridgement of Dr. Adam Smith's Inquiry","0019500300"],["The story of Lady Juliana Harley. A novel. In letters.","0023100401"],["Clarissa. Or, the history of a young lady: comprehending the","0027400303"],["An illustration and mensuration of solid geometry; in seven books:","0030300600"],["Letters addressed to Sir Thomas Charles Bunbury, Member of Parliament","0052101400"],["The following acts of Parliament are published by order of","0067001000"],["The first six books of Milton's Paradise lost, rendered into","0103200900"],["On the death of Mr. Edmund Smith, late student of","0111501900"],["Plans of education; with remarks on the systems of other","0129900300"],["A reply to the Answer of the Rev. Dr. Maskelyne,","0139600400"],["The catechism of the Church of England: With Notes Explanatory;","0193101300"],["Regulations for managing the Hospital for the maintenance and education","0203900200"],["The greatest good, or the greatest evil, deriv'd to mankind","0220500800"],["Charity to orphans and other necessitous children, described and recommended.","0243200900"],["Warning and admonition to the people of Scotland, by the","0247700600"],["Eudosia: or, a poem on the universe.","0274300400"],["A practical discourse concerning death. By William Sherlock, D. D.","0343400800"],["Bellona; or, the genius of Britain; a poetical vision :","0391000700"],["A collection of interesting anecdotes, memoirs, allegories, essays, and poetical","0405900500"],["A proposal for establishing a professorship of the Persian language","0484600300"],["The practice of divine love revised: being an exposition of","0521700700"],["Infidelity the ruin of a people; or, Unbelief the Damning","0543700500"],["The history of the life of King Henry the Second,","0588200101"],["Remarks on Dr Sharp's pieces on the words Elohim and","0602600100"],["The life of Augustus C\u00e6san, containing the most remarkable events","0628000201"],["A discourse of Baptism, in answer to the Reverend Mr.","0679102200"],["Twenty-Seven sermons, on various important subjects. By the Reverend William","0711200600"],["Dissertations on the foederal transactions between God and his church,","0858000900"],["Three dialogues between Hylas and Philonous. In opposition to sceptics","0983900300"],["The art of managing popular elections. Being a complete collection","1090302200"],["The mysterious congress. A letter from Aix la Chappel, detecting","1209100400"],["The conscious lovers. A comedy, by Sir Richard Steele. As","1210900300"],["Elements of chemistry. By M. I. A. Chaptal, Chevalier of","1245401402"],["Memorial for Francis Lord Napier, defender; against Captain William Livingston,","1276004000"],["Unto the Right Honourable, the Lords of Council and Session,","1276103800"],["An introductory lecture to a course of chemistry: read at","1294900900"],["Pet. R. Dreghorn, Esq; against Lord Swinton's interlocutor. Robert Sym,","1297901900"],["A specimen of a select collection of drawings, from the","1304701100"],["A second conversation between Ebenezer, a seceder, and John, a","1337400600"],["Polypody. The ancient doctrine of the virtues of that herb,","1529202000"],["The India courier. Containing the occurrences of Europe, &c. together","1551700800"],["The book of common prayer, and administration of the sacraments,","1628601100"],["The Burnisher.","1657600800"],["The Gentleman and lady's key, to polite literature; Or A","1734900400"],["\"S ...

# %% [markdown]
# ### History

# %%
histCategories = ['lcsh_history', 'nontravel_history', 'lcsh_antiquities']

# %%
allaccdf[allaccdf.Model.isin(histCategories)]
# Out:
#                 Model        bestaccuracy  average_bestaccuracy  total files
# 36  nontravel_history  [0.79, 0.79, 0.78]                  78.7        300.0
# 15       lcsh_history   [0.88, 0.86, 0.9]                  88.0        300.0
# 13   lcsh_antiquities    [0.92, 0.9, 0.9]                  90.7        279.0

# %%
df = pd.read_csv(modelBasePath + 'lcsh\\history\\history.1\\' + 'lcsh_history.csv')
makefig(df)
# Out:
# <div>                            <div id="46add61e-7cb2-41df-82af-5a10c1383e69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46add61e-7cb2-41df-82af-5a10c1383e69")) {                    Plotly.newPlot(                        "46add61e-7cb2-41df-82af-5a10c1383e69",                        [{"customdata":[["Liberal opinions, or, the history of Benignus. A new edition","0009000103"],["Novels, tales, and stories. Written originally in French, by Margaret","0009300100"],["A treatise on the various kinds and qualities of foods:","0010402600"],["The excursion. In two volumes. By Mrs. Brooke; Author of","0012900801"],["All's right at last: or, the history of Miss West.","0013100102"],["The fair impostor, a novel. In three volumes. ...","0024300301"],["The constitution and bye-laws, together with a summary abstract of","0024900300"],["The history of Israel Jobson, the wandering Jew. Giving a","0032900900"],["The history of Lady Barton, a novel, in letters, by","0033500301"],["Ellen, Countess of Castle Howel, a novel, in four volumes.","0037000104"],["Theologia reformata: or, discourses on those graces and duties which","0043100300"],["Tidings from Wallingford. By William Huntington, S.S. Minister of the","0043301100"],["A christian library. Consisting of extracts from and abridgments of","0046400142"],["Fables by the late Mr. Gay. In One Volume Complete.","0048900600"],["A correspondence between Noctua Aurita, of the desert, and Philomela,","0056201000"],["The young gentleman and lady's monitor and English teacher's assistant;","0056501600"],["Love in many masks: as altered by J. P. Kemble,","0057800200"],["The committee: or, the faithful Irishman. A comedy. Written by","0059000500"],["Edgar and Emmeline. A comedy, in two acts. Written by","0059001100"],["A new edition of the appeal of a neglected naval","0062002100"],["The holy Bible, containing the Old Testament and the New:","0071300200"],["The advantages and disadvantages of the marriage-state, as entered into","0079801200"],["The works of Alexander Pope, Esq; In four volumes, complete.","0088600404"],["The life of Mr. Richard Savage, son of the Earl","0095201800"],["The contrast: a novel. In two volumes. By E. S.","0099605202"],["Flowers of poesy, consisting of elegies, songs, sonnets, &c.","0100000400"],["Liberty in the suds; or, modern characters. In a letter","0109301900"],["The life and actions of Frederic the victorious King of","0109900400"],["Fables. By the late Mr Gay. In two volumes.","0110000202"],["An essay on the hereditary and indefeasible right of kings.","0113200600"],["A supplement to The office and duty of executors: Containing","0119600200"],["A state of the dispute between Sir Robert Clayton, Bart.","0121100800"],["An act for confirming and establishing two several articles of","0122500400"],["The court of Thespis; being a collection of the most","0133901700"],["Mutual charity, the most perfect Bond of Christian Unity. A","0134703800"],["The wooden age. A Satyrical poem. Humbly Inscrib'd to William","0146402500"],["Charity the bond of perfectness: or, Christ's law of love,","0148203600"],["The works of Mr. Francis Beaumont, and Mr. John Fletcher.","0153900204"],["The pittiad: a satire. By Doll Common.","0158901900"],["Papers respecting the negociation for a renewal of the East-India","0170501000"],["Thoughts on the suspension of the Habeas Corpus Act.","0172302300"],["The practical justice of peace, and parish and ward-officer: or,","0174500202"],["Sermons on the following subjects: The care of the soul,","0179100700"],["An abstract of midwifry, for the use of the lying-in","0179401300"],["Maria Cecilia: or life and adventures of the daughter of","0184300101"],["Letters from the late reverend James Hervey, A. M. Rector","0191 ...

# %%
historyTotalsdf = compTotalsdf.loc[['lcsh_history', 'lcsh_antiquities', 'nontravel_history'], bibSourceList+['alltravel']].copy()
historyTotalsdf.T.sort_values('lcsh_history')
# Out:
# Model            lcsh_history  lcsh_antiquities  nontravel_history
# gove                     67.4              54.3               56.3
# robinson_w               69.7              71.8               51.7
# btw_europe               70.9              76.3               51.1
# andrews                  71.0              80.7               51.1
# irishmcveagh             71.9              79.7               50.3
# ncco_travelnarr          73.1              74.9               55.4
# btw_w                    74.1              74.6               54.3
# tee                      74.1              68.6               54.9
# murray                   76.6              68.6               54.2
# ncco_c19trav             78.3              80.7               56.7
# leask                    78.6              77.0               59.5
# bdanth                   78.7              75.6               56.3
# brynmawr                 84.8              83.1               58.6
# cox                      84.8              78.4               63.2
# alltravel                86.1              83.4               62.2

# %%
fig = px.imshow(historyTotalsdf.round(2))
fig.show()
# Out:
# <div>                            <div id="7a4036df-ac96-4028-bc81-3af82c01e646" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a4036df-ac96-4028-bc81-3af82c01e646")) {                    Plotly.newPlot(                        "7a4036df-ac96-4028-bc81-3af82c01e646",                        [{"coloraxis":"coloraxis","name":"0","x":["andrews","bdanth","brynmawr","btw_europe","btw_w","cox","gove","irishmcveagh","leask","murray","ncco_c19trav","ncco_travelnarr","robinson_w","tee","alltravel"],"y":["lcsh_history","lcsh_antiquities","nontravel_history"],"z":[[71.0,78.7,84.8,70.9,74.1,84.8,67.4,71.9,78.6,76.6,78.3,73.1,69.7,74.1,86.1],[80.7,75.6,83.1,76.3,74.6,78.4,54.3,79.7,77.0,68.6,80.7,74.9,71.8,68.6,83.4],[51.1,56.3,58.6,51.1,54.3,63.2,56.3,50.3,59.5,54.2,56.7,55.4,51.7,54.9,62.2]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}, ...

# %% [markdown]
# # Locations

# %%
locpath = modelBasePath + 'locations//'

# %%
locdf = accuracy_summary(locpath)
locdf.sort_values('average_bestaccuracy')
# Out:
#           Model        bestaccuracy  average_bestaccuracy  total files
# 1     loc_carib  [0.73, 0.86, 0.77]                  78.7         28.0
# 9   loc_oceania  [0.87, 0.87, 0.87]                  87.0         15.0
# 10   loc_seasia  [0.89, 0.91, 0.94]                  91.3         48.0
# 8   loc_northam  [0.93, 0.93, 0.93]                  93.0        269.0
# 7     loc_meast  [0.93, 0.94, 0.93]                  93.3         73.0
# 6   loc_latinam  [0.94, 0.94, 0.93]                  93.7         75.0
# 5   loc_ireland  [0.95, 0.93, 0.93]                  93.7         30.0
# 2     loc_easia   [0.9, 0.96, 0.96]                  94.0         34.0
# 4        loc_gb  [0.94, 0.94, 0.95]                  94.3        300.0
# 3    loc_europe  [0.96, 0.95, 0.96]                  95.7        299.0
# 0    loc_africa  [0.97, 0.97, 0.98]                  97.3        104.0

# %%
locdf_1 = pd.read_csv(locpath +'location.3\\loc_africa.csv')
makefig(locdf_1)
# Out:
# <div>                            <div id="955b2bc5-65af-4a7f-8803-a27aeeeb020a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("955b2bc5-65af-4a7f-8803-a27aeeeb020a")) {                    Plotly.newPlot(                        "955b2bc5-65af-4a7f-8803-a27aeeeb020a",                        [{"customdata":[["Memoirs of Antonina, Queen of Abo. Displaying her private intrigues,","0006000501"],["A tale of the times. By the author of A","0013800101"],["Siberian anecdotes, a novel. In three volumes. Containing real histories","0021700103"],["The irretrievable abyss: Humbly addressed to both Houses of Parliament;","0038501900"],["Political thoughts.","0044301200"],["A copy of Thompson's Justification, founded on the Solid Principles","0045102500"],["The plays of William Shakspeare, complete, in eight volumes. ...","0058000103"],["As you like it. A comedy. Written by William Shakspeare.","0076501300"],["Jordan's elixir of life, and cure for the spleen; or,","0106400600"],["Velina: a poetical fragment.","0146601500"],["The reasonableness of an act of grace and indemnity, at","0147303800"],["Chaubert; or, the misanthrope. A tragic drama.","0163801800"],["Medical advice to the inhabitants of warm climates, on the","0165800400"],["Sermons on various subjects, by George Walker, F.R.S. Minister of","0197100601"],["An abstract of a treatise, intituled, Free Parliaments: written by","0250204500"],["The mourtray family. A novel. In four volumes. ...","0250400102"],["Memoirs of Mark Hildesley, D.D. Lord Bishop of Sodor and","0379600200"],["Principles of moral and political science; being chiefly a retrospect","0382500302"],["An attempt to prove the materiality of the soul, by","0428100900"],["Dialogues on some important subjects, drawn up After the Manner","0543402300"],["Chrysal: or, the adventures of a guinea. Wherein are exhibited","0559800102"],["The principles of perspective, explained in a genuine theory, and","0580300300"],["Considerations on the opinion stated by the Lords of the","0586100600"],["The natural history of British birds; or, a selection of","0622700201"],["A letter to the Dilettanti Society, respecting the obtention of","0694900700"],["A defense of the answer to Mr. Whiston's suspicions, and","0702301200"],["The devil to pay: or, the Wives Metamorphos'd. An opera.","0758600700"],["The whole works of the Right Honourable Duncan Forbes, Late","0910100500"],["The history of England, from the invasion of Julius C\u00e6sar","0933200104"],["Sermons on the great doctrines and duties of Christianity: proving,","0934901000"],["A letter to the inhabitants of Manchester, on the exportation","0954301700"],["The sunday service of the Methodists; with other occasional services.","1075100100"],["Two sermons, preached at Mill-Hill chapel, in Leeds, on the","1106300100"],["Forgery detected. By which is evinced how groundless are all","1110500100"],["The new Testament of our Lord and Saviour Jesus Christ.","1162600100"],["Thoughts, on the cause of the increase of the poor,","1287101700"],["An address to the people of Great Britain. By a","1287301400"],["Some particulars of the life and experience of Nicholas Manners.","1366700200"],["The Christian preacher delineated.","1568100300"],["An Authentic narrative of some particular occurrences which have lately","1635501300"],["Practical remarks upon indigestion : particularly as connected with bilious","chi.72703223"],["An analysis of the Egyptian mythology : to which is","hvd.32044018892372"],["The whole works of the Right Rev. Jeremy Taylor :","hvd.32044069689248"],["Memoirs of George Whitehead, a minister of the Gospel in","hvd.32044081824989"],["German stories : selected from the works of Hoffman, De","hvd.32044087118170"],["The last days of the Portuguese c ...

# %%
locdf_2 = pd.read_csv(locpath +'location.1\\loc_europe.csv')
makefig(locdf_2)
# Out:
# <div>                            <div id="2c2352a0-b5f0-491f-bce3-f70d3f3df193" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c2352a0-b5f0-491f-bce3-f70d3f3df193")) {                    Plotly.newPlot(                        "2c2352a0-b5f0-491f-bce3-f70d3f3df193",                        [{"customdata":[["A trip to Portugal. Or, a view of their strength","0003501100"],["An account of Switzerland, and the Grisons: As also Of","0079300400"],["A picturesque description of Switzerland, by the Marquis de Langle.","0079300500"],["Travelling memorandums, made in a tour upon the continent of","0079600203"],["A review of the characters of the principal nations in","0084700501"],["A review of the characters of the principal nations in","0084700502"],["A journal of a summer's excursion, by the road of","0085200100"],["Travels in Sicily and Malta: translated from the French of","0085200400"],["Journal of travels made through the principal cities of Europe:","0085301400"],["The travels of reason in Europe. Translated from the French","0085400200"],["Letters from several parts of Europe, and the East. Written","0085401001"],["Letters from several parts of Europe, and the East. Written","0085401002"],["A journey through the Austrian Netherlands. Containing the modern history","0086300700"],["The history of Lapland: shewing the original, manners, habits, religion","0141200100"],["The geography and history of Mons: or, a description of","0151700600"],["An accurate description of the island and kingdom of Sicily;","0162600800"],["Travels through Denmark and some parts of Germany: by way","0168800100"],["Ideas, suggested on the spot in a late excursion through","0168800300"],["A geographical and statistical account of the Cisalpine Republic, and","0169500100"],["Sentimental letters on Italy; written in French by President Dupaty,","0175400301"],["Sentimental letters on Italy; written in French by President Dupaty,","0175400302"],["Sketches of the natural, civil, and political state of Swisserland;","0175500300"],["Gleanings through Wales, Holland and Westphalia, with views of peace","0181200201"],["Gleanings through Wales, Holland and Westphalia, with views of peace","0181200202"],["Gleanings through Wales, Holland and Westphalia, with views of peace","0181200203"],["The beneficent bee: or, Traveller's Companion. Containing Each Day's Observation,","0181400100"],["A tour through France, Flanders, and Germany; in a letter","0185600900"],["A short account of a late journey to Tuscany, Rome,","0204100200"],["Letters from a young painter abroad to his friends in","0241400500"],["A sentimental journey. Intended as a sequel to Mr. Sterne's.","0245800501"],["A sentimental journey. Intended as a sequel to Mr. Sterne's.","0245800502"],["An account of Denmark, ancient and modern. Containing its history,","0294300800"],["Travels in the two Sicilies, by Henry Swinburne, Esq. In","0309600302"],["An historical description of ancient and modern Rome; also of","0309700401"],["An historical description of ancient and modern Rome; also of","0309700402"],["Reflections of ***** being a series of politcal maxims, illustrated","0386900700"],["An extract from the observations made in a tour to","0424600300"],["Some letters, containing an account of what seem'd most remarkable","0443300500"],["Cursory remarks made in a tour through some of the","0505400100"],["A new account of Italy. Containing a description of all","0505900400"],["Bishop Burnet's travels through France, Italy, Germany, and Switzerland: ...","0554000500"],["Memoirs of the Right Honourable Lord Viscount Cherington, containing a","0560300301"],["Memoirs of the Right Honourable Lord Viscount Cherington, containing a","0560300302"],["A descriptive journey through the in ...

# %%
locList = locdf['Model'].tolist()

# %% [markdown]
# In the small collection of titles about the Caribbean, the low accuracy is helped along by *Whartoniana* (0595000601) with its collection of verses, and an economic tract---with no mention of the Caribbean beyond the South Sea bubble---entitled *The Present state of the national debt* (1447101600). Oceania, despite being an even smaller corpus, is still more accuarte, at 87%, and from there, the other locations are all above 91%. Titles describing Africa are relatively easy for models to predict, with one of the highest accuracies across all models at 97.3%; European models, despite including locations ranging from Sweden to Italy, also have high accuracies.

# %%
locCategories = accuracy_summary(locpath)['Model'].tolist() + genList
locTotalsdf = compTotalsdf.loc[locCategories, locCategories].copy()

# %%
locTotalsdf.drop(genList, axis=1).mean().sort_values().round(1)
# Out:
# loc_carib      77.4
# loc_gb         79.2
# loc_oceania    79.6
# loc_latinam    82.6
# loc_ireland    82.8
# loc_northam    82.9
# loc_meast      83.7
# loc_seasia     84.5
# loc_easia      85.0
# loc_europe     85.1
# loc_africa     86.2
# dtype: float64

# %%
fig = px.imshow(locTotalsdf.round(1))
fig.show()
# Out:
# <div>                            <div id="f8531ae0-ea21-4902-93ff-b4a1938bd0da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8531ae0-ea21-4902-93ff-b4a1938bd0da")) {                    Plotly.newPlot(                        "f8531ae0-ea21-4902-93ff-b4a1938bd0da",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_oceania","loc_northam","loc_latinam","loc_carib","loc_easia","loc_meast","loc_ireland","loc_europe","loc_seasia","loc_africa","loc_gb","alltravel","lcsh_traveltag"],"y":["loc_oceania","loc_northam","loc_latinam","loc_carib","loc_easia","loc_meast","loc_ireland","loc_europe","loc_seasia","loc_africa","loc_gb","alltravel","lcsh_traveltag"],"z":[[null,77.5,84.8,76.0,86.2,82.6,74.9,76.3,83.1,86.9,73.0,76.5,77.2],[77.5,null,82.0,80.7,80.9,77.5,85.4,88.4,82.8,82.8,80.9,86.1,89.6],[84.8,82.0,null,84.7,88.7,87.8,81.5,79.2,88.6,93.0,64.6,77.4,79.0],[76.0,80.7,84.7,null,74.1,74.9,76.1,76.1,81.6,80.9,74.2,73.6,76.0],[86.2,80.9,88.7,74.1,null,89.9,81.9,87.2,88.1,93.4,82.4,82.3,84.5],[82.6,77.5,87.8,74.9,89.9,null,80.9,89.6,91.1,92.7,75.6,79.0,82.3],[74.9,85.4,81.5,76.1,81.9,80.9,null,89.9,81.3,84.4,91.6,80.0,85.2],[76.3,88.4,79.2,76.1,87.2,89.6,89.9,null,84.1,86.4,87.5,86.0,90.0],[83.1,82.8,88.6,81.6,88.1,91.1,81.3,84.1,null,93.0,77.0,80.8,82.3],[86.9,82.8,93.0,80.9,93.4,92.7,84.4,86.4,93.0,null,74.2,82.1,85.1],[73.0,80.9,64.6,74.2,82.4,75.6,91.6,87.5,77.0,74.2,null,83.0,86.3],[76.5,86.1,77.4,73.6,82.3,79.0,80.0,86.0,80.8,82.1,83.0,null,88.4],[77.2,89.6,79.0,76.0,84.5,82.3,85.2,90.0,82.3,85.1,86.3,88.4,null]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"typ ...

# %%
fig = px.imshow(compTotalsdf.loc[['loc_gb'], compTotalsdf.columns.str.contains('loc')].round(1))
fig.show()
# Out:
# <div>                            <div id="cdc2143e-0675-4768-9c81-b77e242c663c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdc2143e-0675-4768-9c81-b77e242c663c")) {                    Plotly.newPlot(                        "cdc2143e-0675-4768-9c81-b77e242c663c",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia"],"y":["loc_gb"],"z":[[74.2,74.2,82.4,87.5,null,91.6,64.6,75.6,80.9,73.0,77.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"sc ...

# %%
compTotalsdfList.loc[['loc_gb'], compTotalsdfList.columns.str.contains('loc')]
# Out:
#                 loc_africa           loc_carib           loc_easia  \
# Model
# loc_gb  [71.8, 76.3, 74.4]  [73.8, 74.8, 74.1]  [80.7, 83.5, 83.0]
#
#                 loc_europe loc_gb         loc_ireland         loc_latinam  \
# Model
# loc_gb  [87.7, 87.9, 86.8]    NaN  [91.5, 91.3, 91.9]  [61.6, 66.9, 65.2]
#
#                  loc_meast         loc_northam         loc_oceania  \
# Model
# loc_gb  [75.8, 76.9, 74.2]  [80.2, 82.8, 79.7]  [70.8, 74.1, 74.1]
#
#                 loc_seasia
# Model
# loc_gb  [76.0, 77.9, 77.2]

# %%
fig = px.imshow(compTotalsdf.loc[['loc_oceania'], compTotalsdf.columns.str.contains('loc')].round(1))
fig.show()
# Out:
# <div>                            <div id="daddd806-cd42-4a52-96e2-f93d4ff09fe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daddd806-cd42-4a52-96e2-f93d4ff09fe4")) {                    Plotly.newPlot(                        "daddd806-cd42-4a52-96e2-f93d4ff09fe4",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia"],"y":["loc_oceania"],"z":[[86.9,76.0,86.2,76.3,73.0,74.9,84.8,82.6,77.5,null,83.1]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type ...

# %%
fig = px.imshow(compTotalsdf.loc[['loc_europe'], compTotalsdf.columns.str.contains('loc')].round(1))
fig.show()
# Out:
# <div>                            <div id="3c9a6698-7e90-41b1-be0b-090719578b3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c9a6698-7e90-41b1-be0b-090719578b3b")) {                    Plotly.newPlot(                        "3c9a6698-7e90-41b1-be0b-090719578b3b",                        [{"coloraxis":"coloraxis","name":"0","x":["loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia"],"y":["loc_europe"],"z":[[86.4,76.1,87.2,null,87.5,89.9,79.2,89.6,88.4,76.3,84.1]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type" ...

# %% [markdown]
# The comparisons are far more interesting, however. (Note that for the location tags, no travel titles overlap in the training corpus, so the travel portion of the models are completely individual.) There are some distinct patterns that appear. Continuing our discussion of Great Britain and Ireland, the model of the descriptions and travel titles of those islands are very similar, at 92.9% accuracy. The other locations similar to Great Brtiain are Europe, at 85 percent, and North America at 83.4%, indicating connections in how writers conceived of these locations. Domestic travel in Great Britain is, however, generally more distinct from other locations, especially Oceania (nearly 50%), the Caribbean, Africa, and east Asia (all below 67%). In turn, models of Oceania are distinct from European, British, and Irish models; instead, Oceania's closest relations are east Asia (92.9%) and Africa (89.9%).
#
# Further questions for this section might include, for example, whether (and how) these models might have evolved over time. North America and
#
# Analyzing by location shifts attention away from our central question of genre, but it does influence our perspective of travel writing, drawing attention to how models of texts about different places may reveal differences in how these locations were conceptualized for a British audience, offering one way of answering Pratt's question of “How has travel and exploration writing *produced* ‘the rest of the world’ for European readerships at particular points in Europe’s [and Great Britain's] expansionist trajectory?” (4). For example, in a more in-depth study focused on individual nations, we could fine-tune our 83.6% prediction rate for European and Latin American countries to consider Pratt's assertion that "It is not surprising, then, to find...British accounts of Italy sounding like...British accounts of Brazil" (10). (The TWDB has 11 'Description and travel' titles about Brazil, and 128 on Italy.)

# %% [markdown]
# ## Countries
#
# I created three models of Italy and Brazil to try to answer Mary Pratt's question re imperial eyes.

# %%
brazil_italy_df = compTotals((modelBasePath+'\\mutual recognition\\comparisonTotals_italybrazil_averages.csv'))

# %%
(brazil_italy_df/100).round(1)
# Out:
#                         loc_country_braziletc  loc_country_italysolo  \
# Model
# loc_country_braziletc                    94.2                   74.8
# loc_country_brazilsolo                   92.1                   74.6
# loc_country_italysolo                    74.8                   97.7
#
#                         loc_country_brazilsolo
# Model
# loc_country_braziletc                     92.1
# loc_country_brazilsolo                    94.2
# loc_country_italysolo                     74.6

# %% [markdown]
# ## Gender

# %%
genderpath = modelBasePath + 'gender//'

# %%
genderTotalsdf = compTotalsdf.loc[['gender_au'], compTotalsdf.columns.tolist()].copy()

# %%
allaccdf[allaccdf.Model.isin(['btw_w', 'robinson_w','gender_au', 'gender_au_vs_non'])]
# Out:
#                Model        bestaccuracy  average_bestaccuracy  total files
# 9   gender_au_vs_non  [0.81, 0.86, 0.83]                  83.3        171.0
# 8          gender_au   [0.89, 0.9, 0.93]                  90.7        171.0
# 5              btw_w  [0.92, 0.91, 0.92]                  91.7        152.0
# 39        robinson_w  [0.94, 0.92, 0.96]                  94.0         45.0

# %%
allaccdf[allaccdf.Model.isin(bibSourceList+genList +['btw_w', 'robinson_w','gender_au', 'gender_au_vs_non'])]
# Out:
#                Model        bestaccuracy  average_bestaccuracy  total files
# 34   ncco_travelnarr    [0.9, 0.7, 0.85]                  81.7         10.0
# 9   gender_au_vs_non  [0.81, 0.86, 0.83]                  83.3        171.0
# 6                cox  [0.87, 0.88, 0.87]                  87.3        300.0
# 0          alltravel  [0.86, 0.88, 0.88]                  87.3        300.0
# 19    lcsh_traveltag     [0.9, 0.9, 0.9]                  90.0        300.0
# 8          gender_au   [0.89, 0.9, 0.93]                  90.7        171.0
# 12      irishmcveagh    [0.9, 0.9, 0.94]                  91.3         55.0
# 5              btw_w  [0.92, 0.91, 0.92]                  91.7        152.0
# 20             leask  [0.93, 0.94, 0.91]                  92.7         96.0
# 1            andrews  [0.94, 0.92, 0.93]                  93.0         63.0
# 4         btw_europe  [0.93, 0.93, 0.93]                  93.0         74.0
# 32            murray  [0.93, 0.94, 0.94]                  93.7        118.0
# 33      ncco_c19trav  [0.93, 0.94, 0.94]                  93.7        180.0
# 10              gove  [0.93, 0.95, 0.94]                  94.0         85.0
# 2             bdanth  [0.93, 0.96, 0.93]                  94.0         60.0
# 39        robinson_w  [0.94, 0.92, 0.96]                  94.0         45.0
# 3           brynmawr  [0.94, 0.95, 0.94]                  94.3        243.0
# 40               tee  [0.96, 0.95, 0.96]                  95.7         81.0

# %%
gender_audf = pd.read_csv(genderpath +'gender.1\\gender_au.csv')
makefig(gender_audf)
# Out:
# <div>                            <div id="263846a5-e77b-46e2-a6e3-da33b7681b67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("263846a5-e77b-46e2-a6e3-da33b7681b67")) {                    Plotly.newPlot(                        "263846a5-e77b-46e2-a6e3-da33b7681b67",                        [{"customdata":[["An historical sketch of the French Revolution from its commencement","0004400700"],["Clarissa. Or, the history of a young lady: comprehending the","0027400303"],["St. Leon: a tale of the sixteenth century. By William","0027600603"],["An essay on the future life of brutes, introduced with","0052600602"],["A commentary upon the book of the Revelation. Wherein The","0056700400"],["A view of the silver coin and coinage of England,","0062500400"],["The contrast: a novel. In two volumes. By E. S.","0099605202"],["The louse-Trap: a poem. In imitation of The mouse-trap.","0100900300"],["The works of Tobias Smollett, M.D. with memoirs of his","0107700108"],["Letters on female education, addressed to a married lady. By","0130000200"],["An acquaintance with God the best support under afflictions. A","0135504700"],["An ode on martial virtue, To which are prefixed observations","0146401600"],["A letter to Mr. Archibald Cleland, occasioned By his full","0194502200"],["Two (united) are better than one alone. A thanksgiving sermon","0210100100"],["Lessons to a young prince, by an old statesman, on","0218001200"],["A form of morning and evening prayer, daily throughout the","0287901400"],["An earnest address to persons recovered from apparent death, in","0306701100"],["Sermons on different occasions, and on practical duties. By the","0319501000"],["The coin-Act. By way of dialogue. Designed for the use","0329901400"],["Hearkening to Jesus. A discourse on Matthew, xvii. 5. By","0333701300"],["A new system of practical husbandry. By John Mills, ...","0367000105"],["The atheists tragedy; or, the honest man's revenge. Written by","0380700800"],["A letter to a young gentleman in prison. By Eubulus.","0385901600"],["The pastor's power, and the people's obedience, briefly stated and","0389201900"],["The miscellaneous works of Oliver Goldsmith; now first uniformly collected.","0393600202"],["The Poems by Allan Ramsay.","0433601000"],["On reconciliation and communion with God. Being the substance of","0441300600"],["An account of the life of Mr. David Brainerd, missionary","0452300200"],["Count Rumford's Experimental essays, political, economical, and philososphical. Essay II.","0463902200"],["A noble king a blessing to a land. A sermon","0466104000"],["A sermon preached before the gentlemen of the St. George's","0466303801"],["A proposal for establishing a professorship of the Persian language","0484600300"],["An essay concerning pestilential contagion: occasion'd by the distemper now","0490600200"],["A survey of the wisdom of God in the creation:","0521900201"],["A sermon, delivered February 19, 1795, being a day of","0578601700"],["Juliania; or, the affectionate sisters. By the author of The","0642101300"],["For the curious young gentlemen and ladies that study and","0653800100"],["The weaver's companion. In two parts. Part I. Containing a","0654000300"],["Six occasional sermons upon the following subjects. Sermon I. Of","0704200500"],["Sermons preached at the parish church of St. John, Manchester;","0767601800"],["The Albion queens: or, the death of Mary Queen of","0778600200"],["The defence of Captain Sutton, as pronounced to the president","0788603100"],["An essay to illustrate some of the most necessary articles","0794701100"],["The monthly catalogue: being an exact account of all books","0825400302"],["The pope's journey to the other worlds, to seek advice","0903200400"],["A sermon on salvation by faith. By ...

# %%
gender_audf = pd.read_csv(genderpath +'gender.2\\gender_au.csv')
makefig(gender_audf)
# Out:
# <div>                            <div id="52a031bf-e88e-4514-af1d-6cfa84be65c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52a031bf-e88e-4514-af1d-6cfa84be65c8")) {                    Plotly.newPlot(                        "52a031bf-e88e-4514-af1d-6cfa84be65c8",                        [{"customdata":[["Carite and Polydorus. To which is prefixed, A treatise on","0001200100"],["A system of surgery. By Benjamin Bell, Member of the","0001700205"],["Essays on the principles of morality and natural religion. In","0036200500"],["A select collection of the most interesting letters on the","0052400302"],["The opinions of John Bull, comprised in an address to","0062303600"],["The history of the Emperor Manalay, and his virtuous wife:","0083701200"],["The key of knowledge; or universal conjuror. Unfolding the mysteries","0090700500"],["Dramas for the use of young ladies.","0094101100"],["Flowers of poesy, consisting of elegies, songs, sonnets, &c.","0100000400"],["The louse-Trap: a poem. In imitation of The mouse-trap.","0100900300"],["Sentimental fables. Translated from the French, with the original and","0122703600"],["A sermon, occasioned by the decease of John Howard, Esq.","0131600300"],["More ghosts! In three volumes. By the wife of an","0148902401"],["Apotheosis basilike: or, a Pindarick ode, Upon the Pious and","0170901300"],["An abstract of midwifry, for the use of the lying-in","0179401300"],["A letter to Mr. Archibald Cleland, occasioned By his full","0194502200"],["A sermon preached at the cathedral church of Sarum, November","0200201200"],["Lessons to a young prince, by an old statesman, on","0218001200"],["Cinthelia; or, a woman of ten thousand. In four volumes.","0238600204"],["The fatal secret; or, truth disguised. A tragedy. Wrote by","0250802100"],["The beau's miscellany. Being a new and curious collection of","0277800700"],["An earnest address to persons recovered from apparent death, in","0306701100"],["Poems on various subjects. By a lady.","0331601600"],["A mirror for the multitude; or, Wilkes and his abettors","0340801400"],["A collection of several authentick accounts of the history and","0345000500"],["A new system of practical husbandry. By John Mills, ...","0367000105"],["Dialogues of the dead. By the late M. de Fenelon,","0389200202"],["The privileges of Britain. A sermon, preached at the meeting-house","0396701400"],["The goat's beard. A fable.","0398900600"],["Plain-Dealing: or, Separation without Schism, and Schism without Separation. Exemplify'd","0427200800"],["The citizen of the world: or, letters from a Chinese","0427500101"],["A collection of the works of that antient, faithful Servant","0445200902"],["Acts and proceedings of the Associate Presbytery, met at Edinburgh,","0466602500"],["An account of a rich illuminated missal executed for John","0480500700"],["[A general abridgment of law and equity alphabetically digested under","0501700300"],["Infidelity the ruin of a people; or, Unbelief the Damning","0543700500"],["Thoughts on the English government. Addressed to the quiet good","0567401200"],["A system of natural philosophy, being a course of lectures","0580800401"],["A familiar epistle from C. Anstey, Esq. to C. W.","0622300800"],["Divine poems and essays on various subjects. Viz. Immanuel; or,","0644800700"],["Divine emblems: or, temporal things spiritualized. Fitted for the use","0644900100"],["The satires of Persius. Translated by William Drummond, Esq. M.","0675200300"],["Experiments upon magnesia alba, quick-lime, and other alcaline substances; By","0682000200"],["Navigation spiritualized; or, a new compass for seamen. To which","0701401100"],["Zechariah; a new translation: with notes, critical, philological, and explanatory;","0703900400"],["Outline of ...

# %%
gender_audf = pd.read_csv(genderpath +'gender.3\\gender_au.csv')
makefig(gender_audf)
# Out:
# <div>                            <div id="fc447c1e-997e-4d66-8149-08fb2bec9bd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc447c1e-997e-4d66-8149-08fb2bec9bd6")) {                    Plotly.newPlot(                        "fc447c1e-997e-4d66-8149-08fb2bec9bd6",                        [{"customdata":[["A summary of universal history; in nine volumes. Exhibiting the","0002500106"],["The history of Major Bromley and Miss Cliffen. ...","0016300202"],["The englishman's manual: containing a general view of the constitution,","0041301700"],["A select collection of the most interesting letters on the","0052400302"],["Texts of scripture freed from vulgar mistakes. By James Boys,","0053300100"],["The holy Bible, containing the Old and New Testaments, Translated","0065700101"],["General regulations for the government of the new goal, at","0078900600"],["The works of Alexander Pope, Esq; ... . Containing his","0088800406"],["The yarmouth tragedy; or, the constant lovers.","0089708600"],["An essay on glandular secretion; containing an experimental enquiry into","0111901000"],["One thing needful; or devout and philosophical exercises on various","0177300600"],["A sermon preached at the cathedral church of Sarum, November","0200201200"],["The important question: a sermon on Matt. xvi. 26. By","0235300900"],["The mourtray family. A novel. In four volumes. ...","0250400102"],["The adopted daughter; or the history of Miss Clarissa B---.","0276901002"],["The beau's miscellany. Being a new and curious collection of","0277800700"],["Sunday reading. Hints to all ranks of people.","0287700300"],["The British Plutarch; or, biographical entertainer. Being a select collection","0292600105"],["Caroline, or the happy marriage; being a poem addressed to","0305300200"],["Anti-Thespis: or, a vindication of the principal performers at Drury-Lane","0306000800"],["Sermons on different occasions, and on practical duties. By the","0319501000"],["Poems on various subjects. By a lady.","0331601600"],["Hearkening to Jesus. A discourse on Matthew, xvii. 5. By","0333701300"],["Unto the Right Honourable the Lords of Council and Session,","0348503700"],["The poetical works of Robert Fergusson, with the life of","0392000700"],["Galba. A dialogue on the navy.","0411100700"],["Veritas redux. Evangelical truths restored: Namely, those concerning God's Eternal","0420400401"],["Emmeline, the orphan of the castle. By Charlotte Smith. In","0485200502"],["A private conference between two Hanoverian ministers at Hanover. Taken","0498300500"],["The vision of prophecy; or, scandal convicted. A poetic epistle","0506800400"],["The British housewife: containing the most approved receipts in roasting,","0542100100"],["A sermon preached at Little St. Helen's, to the society","0543300600"],["Considerations on the opinion stated by the Lords of the","0586100600"],["The natural history of British birds; or, a selection of","0622700201"],["The dramatic works of John O'Keeffe, Esq. Published under the","0653300403"],["The weaver's companion. In two parts. Part I. Containing a","0654000300"],["A farther vindication of Mr. Barclay's scheme, in reply to","0656200500"],["A parallel of the antient architecture with the modern, in","0667201300"],["The satires of Persius. Translated by William Drummond, Esq. M.","0675200300"],["Navigation spiritualized; or, a new compass for seamen. To which","0701401100"],["The secret policy of the English Society of Jesus. Discover'd","0725600400"],["An enquiry into the question, Whether the Brother of the","0764300700"],["The lives and characters of the most eminent vvriters of","0765300101"],["A sermon preached at the anniversary meeting of the Sons","0777801000"],["Meditations and contemplations. In two volumes. Contai ...

# %%
fig = px.imshow(genderTotalsdf)
fig.show()
# Out:
# <div>                            <div id="90ccb460-bbde-4c48-a350-3e63771f1ae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90ccb460-bbde-4c48-a350-3e63771f1ae3")) {                    Plotly.newPlot(                        "90ccb460-bbde-4c48-a350-3e63771f1ae3",                        [{"coloraxis":"coloraxis","name":"0","x":["alltravel","andrews","bdanth","brynmawr","btw_europe","btw_w","cox","fictitious","gender_au","gender_au_vs_non","gove","imagfiction","irishmcveagh","lcsh_antiquities","lcsh_fiction","lcsh_history","lcsh_imaginary","lcsh_source","lcsh_title_poetry","lcsh_traveltag","leask","loc_africa","loc_carib","loc_easia","loc_europe","loc_gb","loc_ireland","loc_latinam","loc_meast","loc_northam","loc_oceania","loc_seasia","murray","ncco_c19trav","ncco_travelnarr","nontravel_fiction","nontravel_history","nontravel_poetry","origbib","robinson_w","tee"],"y":["gender_au"],"z":[[79.3,80.7,83.4,86.4,82.4,91.7,74.7,73.0,null,74.4,81.2,81.6,79.1,71.5,79.3,72.4,82.5,83.5,73.2,83.5,78.8,78.7,76.2,73.9,88.1,80.9,79.4,78.4,82.0,84.4,71.9,78.6,80.7,83.7,73.1,70.1,52.8,47.2,80.8,85.1,78.3]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>Model: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern" ...

# %%
# btw = pd.read_csv(genderpath +'gender.1\\btw_w.csv')
# makefig(btw)

# %%
# btw = pd.read_csv(genderpath +'gender.1\\btw_w.csv')
# makefig(btw)

# %%
# robdf = pd.read_csv(genderpath +'gender.1\\robinson_w.csv')
# makefig(robdf)
